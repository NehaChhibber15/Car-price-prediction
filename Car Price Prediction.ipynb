# %% [markdown]
# # Problem Statement

# %% [markdown]
# With the covid 19 impact in the market, we have seen lot of changes in the car market. Now some
# cars are in demand hence making them costly and some are not in demand hence cheaper. So, here we need to predict current probable price of the cars.

# %% [markdown]
# # Data Collection

# %% [markdown]
# Here, we have extracted data from few resources.

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
import warnings
warnings.filterwarnings('ignore')

# %%
driver= webdriver.Chrome(r"C:/Users/Suncity/Downloads/chromedriver.exe")

# %%
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"
driver.get(url)

# %%
#1000 time we scroll down by 10000 in order to scroll the website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,10000)")
#creating empty list

Brand=[]
Model=[]
Price=[]
Distance=[]
Fuel_type=[]
Transmission=[]
Owner=[]

#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                        Brand Transmission                             Model  \
# 0           2012 Ford Fiesta       Manual            TITANIUM DIESEL Manual
# 1    2012 Maruti Swift Dzire       Manual                  VDI BS IV Manual
# 2         2014 Maruti Ertiga       Manual                    VDI ABS Manual
# 3          2012 Maruti Swift       Manual                        ZXI Manual
# 4    2013 Maruti Swift Dzire       Manual                  VDI BS IV Manual
# ..                       ...          ...                               ...
# 745       2019 Maruti Baleno       Manual              DELTA 1.2 K12 Manual
# 746    2014 Volkswagen Vento       Manual            HIGHLINE DIESEL Manual
# 747       2014 Ford Ecosport    Automatic  1.5 TITANIUM TI VCT AT Automatic
# 748        2020 Maruti Swift       Manual                        VXI Manual
# 749          2017 Honda WR-V       Manual           1.5 i-DTEC VX MT Manual
#
#         Distance Fuel_type      Price      Owner
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for banglore
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[6]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                         Brand Transmission                             Model  \
# 0            2012 Ford Fiesta       Manual            TITANIUM DIESEL Manual
# 1     2012 Maruti Swift Dzire       Manual                  VDI BS IV Manual
# 2          2014 Maruti Ertiga       Manual                    VDI ABS Manual
# 3           2012 Maruti Swift       Manual                        ZXI Manual
# 4     2013 Maruti Swift Dzire       Manual                  VDI BS IV Manual
# ...                       ...          ...                               ...
# 1223       2019 Ford Ecosport       Manual           1.5TITANIUM TDCI Manual
# 1224          2017 Honda Jazz    Automatic                1.2 V AT Automatic
# 1225       2017 Ford Ecosport       Manual  1.0 ECOBOOST TITANIUM OPT Manual
# 1226   2015 Hyundai Grand i10       Manual          ASTA 1.1 (O) CRDI Manual
# 1227         2012 Hyundai i10       Manual        SPORTZ 1.2 KAPPA2 O Manual
#
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for Mumbai
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[4]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                         Brand Transmission                       Model  \
# 0            2012 Ford Fiesta       Manual      TITANIUM DIESEL Manual
# 1     2012 Maruti Swift Dzire       Manual            VDI BS IV Manual
# 2          2014 Maruti Ertiga       Manual              VDI ABS Manual
# 3           2012 Maruti Swift       Manual                  ZXI Manual
# 4     2013 Maruti Swift Dzire       Manual            VDI BS IV Manual
# ...                       ...          ...                         ...
# 2410  2016 Maruti Swift Dzire       Manual            VDI BS IV Manual
# 2411       2014 Hyundai Verna       Manual  FLUIDIC 1.6 SX VTVT Manual
# 2412     2014 Maruti Alto K10       Manual                  LXI Manual
# 2413  2018 Maruti Wagon R 1.0       Manual              LXI CNG Manual
# 2414         2011 Hyundai i20       Manual             ASTA 1.2 Manual
#
#          Distance     Fuel_type      Price      Owner
# 0       68,356 km        Diesel  ₹2,61,099  2nd Owner
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for Kolkata
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[9]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                         Brand Transmission                   Model  \
# 0            2012 Ford Fiesta       Manual  TITANIUM DIESEL Manual
# 1     2012 Maruti Swift Dzire       Manual        VDI BS IV Manual
# 2          2014 Maruti Ertiga       Manual          VDI ABS Manual
# 3           2012 Maruti Swift       Manual              ZXI Manual
# 4     2013 Maruti Swift Dzire       Manual        VDI BS IV Manual
# ...                       ...          ...                     ...
# 2691  2014 Maruti Wagon R 1.0       Manual              VXI Manual
# 2692  2015 Maruti Wagon R 1.0       Manual              VXI Manual
# 2693         2019 Maruti Alto       Manual              VXI Manual
# 2694     2018 Maruti Alto 800       Manual              VXI Manual
# 2695     2015 Maruti Alto 800       Manual              LXI Manual
#
#          Distance Fuel_type      Price      Owner
# 0       68,356 km    Diesel  ₹2,61,099  2nd Owner
# 1     1,26,803 km    Diesel  ₹2,74,099  1st Owner
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for chennai
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[8]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                         Brand Transmission  \
# 0            2012 Ford Fiesta       Manual
# 1     2012 Maruti Swift Dzire       Manual
# 2          2014 Maruti Ertiga       Manual
# 3           2012 Maruti Swift       Manual
# 4     2013 Maruti Swift Dzire       Manual
# ...                       ...          ...
# 3350     2018 Maruti Alto 800       Manual
# 3351     2018 Maruti Alto 800       Manual
# 3352     2015 Maruti Alto K10    Automatic
# 3353         2011 Maruti Alto       Manual
# 3354        2019 Renault Kwid    Automatic
#
#                                    Model     Distance Fuel_type      Price  \
# 0                 TITANIUM DIESEL Manual    68,356 km    Diesel  ₹2,61,099
# 1                       VDI BS IV Manual  1,26,803 km    Diesel  ₹2,74,099
# 2                         VDI ABS Manual    64,013 km    Diesel  ₹4,91,299
# 3                             ZXI Manual    79,744 km    Petrol  ₹3,95,299
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for Pune
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[5]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                         Brand Transmission                    Model  \
# 0            2012 Ford Fiesta       Manual   TITANIUM DIESEL Manual
# 1     2012 Maruti Swift Dzire       Manual         VDI BS IV Manual
# 2          2014 Maruti Ertiga       Manual           VDI ABS Manual
# 3           2012 Maruti Swift       Manual               ZXI Manual
# 4     2013 Maruti Swift Dzire       Manual         VDI BS IV Manual
# ...                       ...          ...                      ...
# 4537       2019 Hyundai VENUE       Manual     1.4 CRDI S MT Manual
# 4538          2012 Honda Brio       Manual   1.2 S MT I VTEC Manual
# 4539       2016 Ford Ecosport       Manual  1.5TITANIUM TDCI Manual
# 4540       2019 Hyundai Creta       Manual   1.4 E PLUS CRDI Manual
# 4541         2019 Honda Civic                         VX CVT i-VTEC
#
#          Distance Fuel_type       Price      Owner
# 0       68,356 km    Diesel   ₹2,61,099  2nd Owner
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for hyderabad
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[7]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                           Brand Transmission                        Model  \
# 0              2012 Ford Fiesta       Manual       TITANIUM DIESEL Manual
# 1       2012 Maruti Swift Dzire       Manual             VDI BS IV Manual
# 2            2014 Maruti Ertiga       Manual               VDI ABS Manual
# 3             2012 Maruti Swift       Manual                   ZXI Manual
# 4       2013 Maruti Swift Dzire       Manual             VDI BS IV Manual
# ...                         ...          ...                          ...
# 4659  2018 Maruti Vitara Brezza    Automatic            ZDI AMT Automatic
# 4660          2018 Renault Kwid    Automatic  RXT 1.0 EASY-R AT Automatic
# 4661    2012 Maruti Swift Dzire       Manual             VDI BS IV Manual
# 4662           2014 Hyundai i10       Manual      SPORTZ 1.1 IRDE2 Manual
# 4663    2019 Hyundai NEW SANTRO    Automatic     1.1 SPORTS AMT Automatic
#
#          Distance Fuel_type      Price      Owner
# ...

# %%
# clicking the search button
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img")
search_button.click()

# %%
# clicking the search button for gurgaon
search_button=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[3]")
search_button.click()

# %%
#scrape brand
brand = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/h2')
for i in brand:
    if i.text is None:
        Brand.append("--")
    else:
        Brand.append(i.text)
time.sleep(5)
#scrape transmission
transmission = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p/span')
for i in transmission:
    if i.text is None:
        Transmission.append("--")
    else:
        Transmission.append(i.text)
time.sleep(5)

#scrape Model
model = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/div[1]/div/p')
for i in model:
    if i.text is None:
        Model.append("--")
    else:
        Model.append(i.text)
time.sleep(5)
#scrape distance
distance = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[1]')
for i in distance:
    if i.text is None:
        Distance.append("--")
    else:
        Distance.append(i.text)
time.sleep(5)

#scrape fuel_type
fuel = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[3]')
for i in fuel:
    if i.text is None:
        Fuel_type.append("--")
    else:
        Fuel_type.append(i.text)
time.sleep(5)
#scrape price
price = driver.find_elements_by_xpath('//div[@class="_19zc5"]/div[2]/span')
for i in price:
    if i.text is None:
        Price.append("--")
    else:
        Price.append(i.text)
time.sleep(5)
#scrape owner
owner = driver.find_elements_by_xpath('//div[@class="_1l4fi"]/ul/li[2]')
for i in owner:
    if i.text is None:
        Owner.append("--")
    else:
        Owner.append(i.text)
time.sleep(5)
#creating dataframe
df=pd.DataFrame({'Brand':Brand,
                'Transmission':Transmission,
                'Model':Model,
                'Distance':Distance,
                'Fuel_type':Fuel_type,
                'Price':Price,
                'Owner':Owner})
df
# Out:
#                         Brand Transmission                             Model  \
# 0            2012 Ford Fiesta       Manual            TITANIUM DIESEL Manual
# 1     2012 Maruti Swift Dzire       Manual                  VDI BS IV Manual
# 2          2014 Maruti Ertiga       Manual                    VDI ABS Manual
# 3           2012 Maruti Swift       Manual                        ZXI Manual
# 4     2013 Maruti Swift Dzire       Manual                  VDI BS IV Manual
# ...                       ...          ...                               ...
# 5413  2014 Maruti Wagon R 1.0       Manual                        LXI Manual
# 5414              2017 BMW X1    Automatic              SDRIVE 20D Automatic
# 5415    2014 Volkswagen Vento       Manual            HIGHLINE DIESEL Manual
# 5416       2014 Ford Ecosport    Automatic  1.5 TITANIUM TI VCT AT Automatic
# 5417        2020 Maruti Swift       Manual                        VXI Manual
#
# ...

# %%
import openpyxl as xls

# %%
excel_file=pd.ExcelWriter("car_features_file.xlsx")

# %%
df.to_excel(excel_file)

# %%
excel_file.save()

# %% [markdown]
# # Description of Data
# Variable Definition

# %% [markdown]
# Brand- It contains the year manufacturing and company name of the car
#
# Transmission-It contains information about whether the car is automatic or manual.
#
# Model- It contains information about the model of the car.
#
# Distance- It contains the number of kilometers  travelled by the car.
#
# Fuel_type- It contain the information about the type of fuel consumed by car
#
# Price: Price of the car
#
# Owner: It contain the information about the number of owner used the car.

# %% [markdown]
# # Model Building

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
from scipy import stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#reading excel file
df=pd.read_excel("car_features_file.xlsx")

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model     Distance Fuel_type       Price  \
# 0               TITANIUM DIESEL Manual    68,356 km    Diesel   ₹2,61,099
# 1                     VDI BS IV Manual  1,26,803 km    Diesel   ₹2,74,099
# 2                       VDI ABS Manual    64,013 km    Diesel   ₹4,91,299
# ...

# %% [markdown]
# # Data Wrangling

# %%
#removing extra space from front and end of the string.
df['Brand_Striped']=df['Brand'].str.strip()

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model     Distance Fuel_type       Price  \
# 0               TITANIUM DIESEL Manual    68,356 km    Diesel   ₹2,61,099
# 1                     VDI BS IV Manual  1,26,803 km    Diesel   ₹2,74,099
# 2                       VDI ABS Manual    64,013 km    Diesel   ₹4,91,299
# ...

# %%
df['Year'] = df['Brand_Striped'].str.split(' ',expand=True)[0]

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model     Distance Fuel_type       Price  \
# 0               TITANIUM DIESEL Manual    68,356 km    Diesel   ₹2,61,099
# 1                     VDI BS IV Manual  1,26,803 km    Diesel   ₹2,74,099
# 2                       VDI ABS Manual    64,013 km    Diesel   ₹4,91,299
# ...

# %%
df['Owner']=df['Owner'].str.strip()

# %%
df['Owner'] = df['Owner'].str.split(' ',expand=True)[0]

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model     Distance Fuel_type       Price  \
# 0               TITANIUM DIESEL Manual    68,356 km    Diesel   ₹2,61,099
# 1                     VDI BS IV Manual  1,26,803 km    Diesel   ₹2,74,099
# 2                       VDI ABS Manual    64,013 km    Diesel   ₹4,91,299
# ...

# %%
df['Distance']=df['Distance'].str.strip()

# %%
df['Distance']=df['Distance'].str.split(' ',expand=True)[0]

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model  Distance Fuel_type       Price Owner  \
# 0               TITANIUM DIESEL Manual    68,356    Diesel   ₹2,61,099   2nd
# 1                     VDI BS IV Manual  1,26,803    Diesel   ₹2,74,099   1st
# ...

# %%
df['Price']=df['Price'].str.strip()

# %%
df['Price']=df['Price'].str.split('₹',expand=True)[1]

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model  Distance Fuel_type      Price Owner  \
# 0               TITANIUM DIESEL Manual    68,356    Diesel   2,61,099   2nd
# 1                     VDI BS IV Manual  1,26,803    Diesel   2,74,099   1st
# ...

# %%
df['Model']=df['Model'].str.strip()

# %%
df['Model']=df['Model'].str.split('Manual',expand=True)[0]

# %%
df
# Out:
#       Unnamed: 0                    Brand Transmission  \
# 0              0         2012 Ford Fiesta       Manual
# 1              1  2012 Maruti Swift Dzire       Manual
# 2              2       2014 Maruti Ertiga       Manual
# 3              3        2012 Maruti Swift       Manual
# 4              4  2013 Maruti Swift Dzire       Manual
# ...          ...                      ...          ...
# 5413        5413  2014 Maruti Wagon R 1.0       Manual
# 5414        5414              2017 BMW X1    Automatic
# 5415        5415    2014 Volkswagen Vento       Manual
# 5416        5416       2014 Ford Ecosport    Automatic
# 5417        5417        2020 Maruti Swift       Manual
#
#                                  Model  Distance Fuel_type      Price Owner  \
# 0                     TITANIUM DIESEL     68,356    Diesel   2,61,099   2nd
# 1                           VDI BS IV   1,26,803    Diesel   2,74,099   1st
# ...

# %%
df.drop(['Unnamed: 0','Brand'],axis=1,inplace=True)

# %%
df
# Out:
#      Transmission                             Model  Distance Fuel_type  \
# 0          Manual                  TITANIUM DIESEL     68,356    Diesel
# 1          Manual                        VDI BS IV   1,26,803    Diesel
# 2          Manual                          VDI ABS     64,013    Diesel
# 3          Manual                              ZXI     79,744    Petrol
# 4          Manual                        VDI BS IV     40,212    Diesel
# ...           ...                               ...       ...       ...
# 5413       Manual                              LXI     69,982    Petrol
# 5414    Automatic              SDRIVE 20D Automatic    47,517    Diesel
# 5415       Manual                  HIGHLINE DIESEL     41,389    Diesel
# 5416    Automatic  1.5 TITANIUM TI VCT AT Automatic    58,943    Petrol
# 5417       Manual                              VXI     22,537    Petrol
#
#           Price Owner Location            Brand_Striped  Year
# ...

# %%
df['Brand'] = df.Brand_Striped.apply(lambda x: x[4:-1])

# %%
df
# Out:
#      Transmission                             Model  Distance Fuel_type  \
# 0          Manual                  TITANIUM DIESEL     68,356    Diesel
# 1          Manual                        VDI BS IV   1,26,803    Diesel
# 2          Manual                          VDI ABS     64,013    Diesel
# 3          Manual                              ZXI     79,744    Petrol
# 4          Manual                        VDI BS IV     40,212    Diesel
# ...           ...                               ...       ...       ...
# 5413       Manual                              LXI     69,982    Petrol
# 5414    Automatic              SDRIVE 20D Automatic    47,517    Diesel
# 5415       Manual                  HIGHLINE DIESEL     41,389    Diesel
# 5416    Automatic  1.5 TITANIUM TI VCT AT Automatic    58,943    Petrol
# 5417       Manual                              VXI     22,537    Petrol
#
#           Price Owner Location            Brand_Striped  Year  \
# ...

# %%
df.drop(['Brand_Striped'],axis=1,inplace=True)

# %%
df
# Out:
#      Transmission                             Model  Distance Fuel_type  \
# 0          Manual                  TITANIUM DIESEL     68,356    Diesel
# 1          Manual                        VDI BS IV   1,26,803    Diesel
# 2          Manual                          VDI ABS     64,013    Diesel
# 3          Manual                              ZXI     79,744    Petrol
# 4          Manual                        VDI BS IV     40,212    Diesel
# ...           ...                               ...       ...       ...
# 5413       Manual                              LXI     69,982    Petrol
# 5414    Automatic              SDRIVE 20D Automatic    47,517    Diesel
# 5415       Manual                  HIGHLINE DIESEL     41,389    Diesel
# 5416    Automatic  1.5 TITANIUM TI VCT AT Automatic    58,943    Petrol
# 5417       Manual                              VXI     22,537    Petrol
#
#           Price Owner Location  Year               Brand
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#finding information about each feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5418 entries, 0 to 5417
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Transmission  5338 non-null   object
#  1   Model         5418 non-null   object
#  2   Distance      5418 non-null   object
#  3   Fuel_type     5418 non-null   object
#  4   Price         5418 non-null   object
#  5   Owner         5418 non-null   object
#  6   Location      5418 non-null   object
#  7   Year          5418 non-null   object
#  8   Brand         5418 non-null   object
# dtypes: object(9)
# memory usage: 381.1+ KB

# %%
#finding null values
df.isnull().sum()
# Out:
# Transmission    80
# Model            0
# Distance         0
# Fuel_type        0
# Price            0
# Owner            0
# Location         0
# Year             0
# Brand            0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Observation: Here we can see that there are few null values present in the data set in Transmission coloum.

# %%
df=df.dropna()

# %% [markdown]
# # Descriptive statistic¶¶
# Measure of tendency Measure of spread

# %%
df
# Out:
#      Transmission                             Model  Distance Fuel_type  \
# 0          Manual                  TITANIUM DIESEL     68,356    Diesel
# 1          Manual                        VDI BS IV   1,26,803    Diesel
# 2          Manual                          VDI ABS     64,013    Diesel
# 3          Manual                              ZXI     79,744    Petrol
# 4          Manual                        VDI BS IV     40,212    Diesel
# ...           ...                               ...       ...       ...
# 5413       Manual                              LXI     69,982    Petrol
# 5414    Automatic              SDRIVE 20D Automatic    47,517    Diesel
# 5415       Manual                  HIGHLINE DIESEL     41,389    Diesel
# 5416    Automatic  1.5 TITANIUM TI VCT AT Automatic    58,943    Petrol
# 5417       Manual                              VXI     22,537    Petrol
#
#           Price Owner Location  Year               Brand
# ...

# %%
df.describe()
# Out:
#        Transmission Model Distance Fuel_type     Price Owner Location  Year  \
# count          5338  5338     5338      5338      5338  5338     5338  5338
# unique            2   556     3376         3      2494     4        8    14
# top          Manual  VXI    23,930    Petrol  4,74,299   1st   Mumbai  2017
# freq           4396   563        4      3732        18  4265     1174   972
#
#                Brand
# count           5338
# unique           114
# top      Maruti Swif
# freq             429

# %% [markdown]
# # Observation: Here, we can see that there are two unique categories present in the transmission i.e., Manual and Automatic.

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Fuel_type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'Petrol + CNG'], dtype=object)

# %%
df['Owner'].unique()
# Out:
# array(['2nd', '1st', '3rd', '4th'], dtype=object)

# %%
df['Location'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Mumbai', 'Kolkata', 'Chennai', 'Pune',
#        'Hyderabad', 'Gurgaon'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array(['2012', '2014', '2013', '2017', '2015', '2016', '2018', '2020',
#        '2019', '2010', '2011', '2021', '2009', '2008'], dtype=object)

# %%
df['Price'].min()
# Out:
# '1,64,299'

# %%
df['Price'].max()
# Out:
# '9,99,899'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5338 entries, 0 to 5417
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Transmission  5338 non-null   object
#  1   Model         5338 non-null   object
#  2   Distance      5338 non-null   object
#  3   Fuel_type     5338 non-null   object
#  4   Price         5338 non-null   object
#  5   Owner         5338 non-null   object
#  6   Location      5338 non-null   object
#  7   Year          5338 non-null   object
#  8   Brand         5338 non-null   object
# dtypes: object(9)
# memory usage: 417.0+ KB

# %% [markdown]
# Observation: Here, we can see that Distance, price, year are in object data type. so we need to convert the data type.

# %%
#removing comma from price
df['Price']=df['Price'].str.replace('[,]','')

# %%
#removing comma from distance
df["Distance"]=df["Distance"].str.replace("[,]","")

# %%
#converting datatype of distance,price,year
df[['Distance', 'Price','Year']] = df[['Distance', 'Price','Year']].apply(pd.to_numeric)
print(df.dtypes)
# Out:
# Transmission    object
# Model           object
# Distance         int64
# Fuel_type       object
# Price            int64
# Owner           object
# Location        object
# Year             int64
# Brand           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5338 entries, 0 to 5417
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Transmission  5338 non-null   object
#  1   Model         5338 non-null   object
#  2   Distance      5338 non-null   int64
#  3   Fuel_type     5338 non-null   object
#  4   Price         5338 non-null   int64
#  5   Owner         5338 non-null   object
#  6   Location      5338 non-null   object
#  7   Year          5338 non-null   int64
#  8   Brand         5338 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 417.0+ KB

# %%
df.describe()
# Out:
#             Distance         Price         Year
# count    5338.000000  5.338000e+03  5338.000000
# mean    44569.123642  6.086260e+05  2016.208692
# std     32017.284396  3.068539e+05     2.243702
# min        58.000000  1.642990e+05  2008.000000
# 25%     21552.000000  4.133240e+05  2015.000000
# 50%     38094.000000  5.331990e+05  2017.000000
# 75%     59495.250000  7.101490e+05  2018.000000
# max    277105.000000  3.556799e+06  2021.000000

# %%
df
# Out:
#      Transmission                             Model  Distance Fuel_type  \
# 0          Manual                  TITANIUM DIESEL      68356    Diesel
# 1          Manual                        VDI BS IV     126803    Diesel
# 2          Manual                          VDI ABS      64013    Diesel
# 3          Manual                              ZXI      79744    Petrol
# 4          Manual                        VDI BS IV      40212    Diesel
# ...           ...                               ...       ...       ...
# 5413       Manual                              LXI      69982    Petrol
# 5414    Automatic              SDRIVE 20D Automatic     47517    Diesel
# 5415       Manual                  HIGHLINE DIESEL      41389    Diesel
# 5416    Automatic  1.5 TITANIUM TI VCT AT Automatic     58943    Petrol
# 5417       Manual                              VXI      22537    Petrol
#
#         Price Owner Location  Year               Brand
# ...

# %% [markdown]
# # Data Visualization

# %%
#exploring transmission feature
df['Transmission'].value_counts().plot(kind='bar')

# %% [markdown]
# Observation: Maximum used cars are available in Manual mode.

# %%
#exploring fuel_type feature
df['Fuel_type'].value_counts().plot(kind='bar')

# %% [markdown]
# Observation: Here, we can see that maximum cars available with petrol feature. However, very few of them available in Petrol + CNG feature.

# %%
#exploring location feature
df['Location'].value_counts().plot(kind='bar')

# %% [markdown]
# Observation: Here, maximum number of used cars are available in Mumbai, Pune location. Very few of them available in hyderabad location.

# %%
#ploting scatter plot between distance and price
plt.scatter(df['Distance'], df['Price'], c ="blue")
plt.xlabel("Distance travelled by car")
plt.ylabel("Price of used cars in rupees") 
# To show the plot
plt.show()

# %% [markdown]
# Observation: Here, we can see inverse relation between these two features. Increase in distance travelled by the car decreases the price of the car.

# %%
sns.set_style('whitegrid')
sns.countplot(x='Location',hue='Transmission',data=df)

# %% [markdown]
# Observation: Here, we can see that maximum automatic and manual used cars are available at Mumbai and Pune location.

# %%
sns.set_style('whitegrid')
sns.countplot(x='Location',hue='Fuel_type',data=df)

# %% [markdown]
# Observation: Here, we can see that used CNG+Petrol cars are not available at Banglore, Kolkata, Chennai, Hyderabad location
# . May be at these location people are not using CNG cars much.
# The ratio of petrol and diesel cars are much less at Banglore, Kolkata, Chennai, hyderabad location. Here, diesel cars are much lesser in number as compare to petrol cars.

# %%
sns.set_style('whitegrid')
sns.countplot(x='Location',hue='Owner',data=df)

# %%
#visualizing relation between fuel type, Price and location
sns.catplot(data=df,x='Fuel_type',y='Price',hue='Location')

# %% [markdown]
# Observation: Here, we can see that used cars of petrol and diesel have more resale value as compareto cng cars.

# %%
#Visualizing relation between Price, location and Owner
sns.barplot(data=df,x='Location',y='Price',hue='Owner')

# %% [markdown]
# Observation: Prices of used cars having 4th owner is less as compare to others.

# %%
#Visualizing relation between Price, location and Owner
sns.barplot(data=df,x='Year',y='Price',hue='Owner')

# %% [markdown]
# Observation: As the year keep on increasing price of car decreases.

# %%
sns.pairplot(df)

# %% [markdown]
# Observation: Here, we can see that the data is skewed. we need to transform it.

# %%
df['Price'].plot.box()

# %% [markdown]
# Observation: Here, we can see that there are outliers present in the price column. This needs to be treated.

# %%
df['Distance'].plot.box()

# %% [markdown]
# Observation: Here, we can see that outliers are present in the given column.

# %%
df.skew()
# Out:
# Distance    1.517711
# Price       2.182329
# Year       -0.483797
# dtype: float64

# %% [markdown]
# Observation:Here, we can see that these values are above 0.55. So, we can consider that it is skewed.

# %%
corr_hmap=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_hmap, annot=True)
plt.show()

# %% [markdown]
# Observation: Here, we can see that there is a strong correlation between model year and Price.

# %%
#transforming the non-numeric data to numeric data by using label encoder
from sklearn.preprocessing import LabelEncoder
co=['Transmission','Location','Model','Fuel_type','Brand']
for col in co:    
    df[col]=LabelEncoder().fit_transform(df[col])

# %%
df
# Out:
#       Transmission  Model  Distance  Fuel_type    Price Owner  Location  Year  \
# 0                1    412     68356          0   261099   2nd         2  2012
# 1                1    432    126803          0   274099   1st         2  2012
# 2                1    430     64013          0   491299   1st         2  2014
# 3                1    541     79744          1   395299   1st         2  2012
# 4                1    432     40212          0   389899   1st         2  2013
# ...            ...    ...       ...        ...      ...   ...       ...   ...
# 5413             1    299     69982          1   306399   1st         3  2014
# 5414             0    359     47517          0  1915799   1st         3  2017
# 5415             1    274     41389          0   427499   1st         3  2014
# 5416             0     88     58943          1   513799   1st         3  2014
# 5417             1    447     22537          1   570599   1st         3  2020
#
#       Brand
# 0        10
# ...

# %%
#As Owner is Normal Categorical data we will perform OneHotEncoding
Owner = df[['Owner']]
Owner = pd.get_dummies(Owner, drop_first=True)
Owner.head()
# Out:
#    Owner_2nd  Owner_3rd  Owner_4th
# 0          1          0          0
# 1          0          0          0
# 2          0          0          0
# 3          0          0          0
# 4          0          0          0

# %%
#concatenate dataframe -->df + Owner
df = pd.concat([df, Owner], axis = 1)

# %%
df
# Out:
#       Transmission  Model  Distance  Fuel_type    Price Owner  Location  Year  \
# 0                1    412     68356          0   261099   2nd         2  2012
# 1                1    432    126803          0   274099   1st         2  2012
# 2                1    430     64013          0   491299   1st         2  2014
# 3                1    541     79744          1   395299   1st         2  2012
# 4                1    432     40212          0   389899   1st         2  2013
# ...            ...    ...       ...        ...      ...   ...       ...   ...
# 5413             1    299     69982          1   306399   1st         3  2014
# 5414             0    359     47517          0  1915799   1st         3  2017
# 5415             1    274     41389          0   427499   1st         3  2014
# 5416             0     88     58943          1   513799   1st         3  2014
# 5417             1    447     22537          1   570599   1st         3  2020
#
# ...

# %%
#droping repeated columns
df.drop(["Owner"],axis=1,inplace=True)

# %%
df
# Out:
#       Transmission  Model  Distance  Fuel_type    Price  Location  Year  \
# 0                1    412     68356          0   261099         2  2012
# 1                1    432    126803          0   274099         2  2012
# 2                1    430     64013          0   491299         2  2014
# 3                1    541     79744          1   395299         2  2012
# 4                1    432     40212          0   389899         2  2013
# ...            ...    ...       ...        ...      ...       ...   ...
# 5413             1    299     69982          1   306399         3  2014
# 5414             0    359     47517          0  1915799         3  2017
# 5415             1    274     41389          0   427499         3  2014
# 5416             0     88     58943          1   513799         3  2014
# 5417             1    447     22537          1   570599         3  2020
#
#       Brand  Owner_2nd  Owner_3rd  Owner_4th
# 0        10          1          0          0
# ...

# %%
#dividing the data into dependent and independent variable
x=df.drop(columns=['Price'],axis=1)
y=df['Price']

# %%
#nomalizing the curve
#transforming the data to reduce skewness
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
x=scale.fit_transform(x)

# %%
#Here we will find out the random state value with which our linear model will learn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Train/Test Split

# %%
#finding best randomstate for train test split
def maxr2_score(regr,a,b):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# r2 score corresponding to 42 is 0.4081326185794325
# r2 score corresponding to 43 is 0.3903505932500483
# r2 score corresponding to 44 is 0.37504567485036633
# r2 score corresponding to 45 is 0.38826298750270494
# r2 score corresponding to 46 is 0.4331478211100751
# r2 score corresponding to 47 is 0.4223298421745888
# r2 score corresponding to 48 is 0.4052371229316716
# r2 score corresponding to 49 is 0.3658741100206334
# r2 score corresponding to 50 is 0.41133920381048195
# r2 score corresponding to 51 is 0.4084935216006812
# r2 score corresponding to 52 is 0.40699874015226656
# r2 score corresponding to 53 is 0.38817248942850713
# r2 score corresponding to 54 is 0.4630368813693738
# r2 score corresponding to 55 is 0.38101531217022755
# r2 score corresponding to 56 is 0.4181200014674732
# r2 score corresponding to 57 is 0.3822970601536192
# r2 score corresponding to 58 is 0.39328205965815133
# r2 score corresponding to 59 is 0.4031775236408095
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=54,test_size=0.20)

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 1}

# %% [markdown]
# # Hyperparameter Tunning

# %%
#importing algorithms
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
#finding best parameter for ridge
alphavalue={'alpha':[0.1,0.01,0.001,0.0001,0]}
rg=Ridge()
grg=GridSearchCV(rg,param_grid=alphavalue)
grg.fit(x,y)
grg.best_params_
# Out:
# {'alpha': 0.1}

# %%
#finding best parameter for lasso
alphavalue={'alpha':[0.1,0.01,0.001,0.0001,0]}
las=Lasso()
lasg=GridSearchCV(las,param_grid=alphavalue)
lasg.fit(x,y)
lasg.best_params_
# Out:
# {'alpha': 0.1}

# %%
#finding best parameter for randomforestregressor
rfr = RandomForestRegressor()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfr, param_grid, n_jobs=-1, cv=5)

grid.fit(x, y)
grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 30}

# %%
#finding best parameter for SVR
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.011808690162769619
# linear
# {'C': 10, 'kernel': 'linear'}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,25)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x,y)
gad.best_params_
# Out:
# {'n_estimators': 11}

# %%
knr=KNeighborsRegressor(n_neighbors=6)
rg=Ridge(alpha=0.1)
las=Lasso(alpha=0.1)
svr=SVR(C= 10, kernel= 'linear')
lr=LinearRegression()
dtr=DecisionTreeRegressor(criterion= 'mse', max_depth= 2, max_leaf_nodes= 5, min_samples_leaf= 20, min_samples_split= 10)
rfr=RandomForestRegressor(bootstrap= True, max_features='auto',min_samples_split= 8,n_estimators=30)
ad=AdaBoostRegressor(n_estimators=1)

# %%
#creating model for algorithm
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('Ridge',rg))
models.append(('Lasso',las))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))

# %%
#importing metrics for finding error
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
#for loop for all the algorithms along with their cross validation
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score=',sc)
    sc1=sc*100
    cvs.append(sc1)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                     weights='uniform')
#
#
# score: 0.7708463315741867
# mean squared error 25709085122.243084
# mean absolute error 96948.15823970038
# r2_score 0.7109619116172949
#
#
# Cross_Val_Score= 0.6377717420515674
#
#
# ************ Ridge ************
#
#
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)
#
#
# score: 0.38789153956793676
# mean squared error 47761251888.278366
# mean absolute error 157535.25096908264
# r2_score 0.46303725399356455
#
#
# Cross_Val_Score= 0.3551025832251094
#
#
# ************ Lasso ************
#
#
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
# ...

# %% [markdown]
# # Evaluating Model

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':sco,'r2score':r2score,'Cross_val_score':cvs})
result
# Out:
#                    Model  Accuracy_score    r2score  Cross_val_score
# 0    KNeighborsRegressor        0.770846  71.096191        63.777174
# 1                  Ridge        0.387892  46.303725        35.510258
# 2                  Lasso        0.387892  46.303682        35.510160
# 3   SupportVectorMachine        0.029591   5.850150         1.960155
# 4        LinearRegressor        0.387892  46.303688        35.510158
# 5  DecisionTreeRegressor        0.238167  31.635503        15.337996
# 6  RandomForestRegressor        0.965159  93.596826        91.227602
# 7      AdaBoostRegressor        0.350539  38.207831        34.887093

# %% [markdown]
# # Saving Best Model

# %%
import joblib
joblib.dump(rfr,'car_price.obj')
# Out:
# ['car_price.obj']

# %% [markdown]
# We further proceed to test the object that we saved using joblib, and create a dataframe of predicted values –

# %% [markdown]
# # Testing Results

# %%
rfr=joblib.load('car_price.obj')
pred= rfr.predict(x_test)
#creating a dataframe with actual and predicted values
predicted_values= pd.DataFrame({'Actual':y_test,'Predicted':pred})

# %%
predicted_values
# Out:
#        Actual     Predicted
# 621    268699  2.842594e+05
# 2656   405399  4.337738e+05
# 3987  1163199  1.129367e+06
# 5108   454499  4.675867e+05
# 4369   999399  9.068618e+05
# ...       ...           ...
# 4837   697099  6.794966e+05
# 819    419899  4.212175e+05
# 2452   991099  8.708091e+05
# 86     585999  6.166785e+05
# 1773   431299  4.202860e+05
#
# [1068 rows x 2 columns]

# %% [markdown]
# We have achieved an accuracy score value of 96%, meaning that we are actually able to predict values quite near to the actual prices, for majority of the rows
